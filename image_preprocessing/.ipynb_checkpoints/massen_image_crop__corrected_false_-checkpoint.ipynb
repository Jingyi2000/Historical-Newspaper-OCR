# %% [markdown]
# ## Image cropping
# OpenCV (Open Source Computer Vision Library) is an open-source computer vision and machine learning software library. It offers a rich set of image processing capabilities, including image transformation, filtering, feature detection, image segmentation, and more. Observations of scanned newspaper documents reveal the following characteristics: 1. The quality of the newspaper scans overall is good. 2. Some of the newspaper pages scanned include unwanted content (for example, a small part of the right page is included in the scan of the left page).

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def auto_crop_image(image_path):
    image = cv2.imread(image_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 1,2)

    kernel = np.ones((5,5), np.uint8)
    dilated_edges = cv2.dilate(edges, kernel, iterations=5)

    mask = np.ones_like(dilated_edges) * 255
    mask[dilated_edges == 255] = 0

    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        sorted_contours = sorted(contours, key=cv2.contourArea, reverse=True)
        x, y, w, h = cv2.boundingRect(sorted_contours[0])
        cropped_image = image[y:y+h, x:x+w]
        return image, cropped_image
    else:
        return image, None

# %%
def auto_crop_image(image_path):
    image = cv2.imread(image_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50, 150)

    kernel = np.ones((5,5), np.uint8)
    dilated_edges = cv2.dilate(edges, kernel, iterations=4)

    mask = np.ones_like(dilated_edges) * 255
    mask[dilated_edges == 255] = 0

    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        sorted_contours = sorted(contours, key=cv2.contourArea, reverse=True)
        x, y, w, h = cv2.boundingRect(sorted_contours[0])
        cropped_image = image[y:y+h, x:x+w]
        return image, cropped_image
    else:
        return image, None

# %%
original_image, cropped_image = auto_crop_image("/home/vivek/Desktop/result/10_bestresult/10_02_00000002_cropped.jpg")
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

axes[0].imshow(cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB))
axes[0].set_title("Original Image")
axes[0].axis('off')

if cropped_image is not None:
    axes[1].imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))
    axes[1].set_title("Cropped Image")
    save_path = '/home/vivek/Desktop/ok.jpg'
    cv2.imwrite(save_path, cropped_image)
else:
    axes[1].text(0.5, 0.5, 'No Change', horizontalalignment='center', verticalalignment='center')
    save_path = '/home/vivek/Desktop/ok.jpg'
    cv2.imwrite(save_path, original_image)
axes[1].axis('off')

plt.show()

# %%
#left

from PIL import Image

pixels_to_crop=80
with Image.open('/home/vivek/Desktop/09_23_00000007_cropped.jpg')as img:
    crop_area=(pixels_to_crop, 0, img.width, img.height)
    cropped_img=img.crop(crop_area)
    cropped_img.save("/home/vivek/Desktop/09_23_00000007_cropped.jpg")

# %%
#right

from PIL import Image

pixels_to_crop=5
with Image.open('/home/vivek/Desktop/right/10_08_00000006_cropped.jpg')as img:
    crop_area=(0,0, img.width-pixels_to_crop,img.height)
    cropped_img=img.crop(crop_area)
    cropped_img.save("/home/vivek/Desktop/right/10_08_00000006_cropped.jpg")

# %%
original_image, cropped_image = auto_crop_image('/home/vivek/Desktop/result/05_bestresult/05_17_00000010_cropped.jpg')
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

axes[0].imshow(cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB))
axes[0].set_title("Original Image")
axes[0].axis('off')

if cropped_image is not None:
    axes[1].imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))
    axes[1].set_title("Cropped Image")
    save_path = '/home/vivek/Desktop/result/05_bestresult/05_17_00000010_cropped.jpg'
    cv2.imwrite(save_path, cropped_image)
else:
    axes[1].text(0.5, 0.5, 'No Change', horizontalalignment='center', verticalalignment='center')
    save_path = '/home/vivek/Desktop/result/05_bestresult/05_17_00000010_cropped.jpg'
    cv2.imwrite(save_path, original_image)
axes[1].axis('off')

plt.show()

# %%
import cv2
import numpy as np
import os
import glob

def auto_crop_image(image_path):
    image = cv2.imread(image_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50, 150)

    kernel = np.ones((5,5), np.uint8)
    dilated_edges = cv2.dilate(edges, kernel, iterations=1)

    mask = np.ones_like(dilated_edges) * 255
    mask[dilated_edges == 255] = 0

    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        sorted_contours = sorted(contours, key=cv2.contourArea, reverse=True)
        x, y, w, h = cv2.boundingRect(sorted_contours[0])
        cropped_image = image[y:y+h, x:x+w]
        return image, cropped_image
    else:
        return image, None
    
source_folder = "/home/vivek/Desktop/Freiheitskampf/1942"
result_folder = "/home/vivek/Desktop/result"


# Ensure the result folder exists
if not os.path.exists(result_folder):
    os.makedirs(result_folder)

for month in range(1, 13):
    month_str = str(month).zfill(2)
    month_source_folder = os.path.join(source_folder, month_str, "files")
    month_result_folder = os.path.join(result_folder, month_str)

    # Ensure the month folder in the result directory exists
    if not os.path.exists(month_result_folder):
        os.makedirs(month_result_folder)

    for day in range(1, 32):  # Assuming up to 31 days in a month
        day_str = str(day).zfill(2)
        day_image_folder = os.path.join(month_source_folder, day_str, "files")

        if os.path.isdir(day_image_folder):
            for image_file in glob.glob(os.path.join(day_image_folder, "*.jpg")):
                original_image, cropped_image = auto_crop_image(image_file)
                
                # Decide which image to save (cropped or original)
                image_to_save = cropped_image if cropped_image is not None else original_image
                if image_to_save is not None:
                    # Create a unique file name to prevent overwriting
                    image_basename = os.path.basename(image_file)
                    new_image_name = f"{month_str}_{day_str}_{image_basename.split('.')[0]}_cropped.jpg" if cropped_image is not None else f"{month_str}_{day_str}_{image_basename}"
                    save_path = os.path.join(month_result_folder, new_image_name)
                    cv2.imwrite(save_path, image_to_save)

# %%
import os

false_folder = "/home/vivek/Desktop/result/03Test_1"
corrected_folder = "/home/vivek/Desktop/result/03Test_2"

for filename in os.listdir(false_folder):
    # 构建完整的文件路径
    file_path = os.path.join(false_folder, filename)
    
    # 检查是否为文件
    if os.path.isfile(file_path):
        # 应用自动裁剪
        _, cropped_image = auto_crop_image(file_path)
        
        # 如果有裁剪结果，保存到目标文件夹
        if cropped_image is not None:
            # 构建保存路径
            save_path = os.path.join(corrected_folder, filename)
            # 保存裁剪后的图片
            cv2.imwrite(save_path, cropped_image)

# %%
import os
false_folder = "/home/vivek/Desktop/result/121"
corrected_folder = "/home/vivek/Desktop/result/12_bestresult"

for filename in os.listdir(false_folder):
    # 构建完整的文件路径
    file_path = os.path.join(false_folder, filename)
    
    # 检查是否为文件
    if os.path.isfile(file_path):
        # 应用自动裁剪
        _, cropped_image = auto_crop_image(file_path)
        
        # 如果有裁剪结果，保存到目标文件夹
        if cropped_image is not None:
            # 构建保存路径
            save_path = os.path.join(corrected_folder, filename)
            # 保存裁剪后的图片
            cv2.imwrite(save_path, cropped_image)

# %%
false_folder="/home/vivek/Desktop/right"
pixels_to_crop=15
for filename in os.listdir(false_folder):
    file_path=os.path.join(false_folder,filename)
    with Image.open(file_path) as img:
        crop_area=(0,0,img.width-pixels_to_crop, img.height)
        cropped_img=img.crop(crop_area)
        cropped_img.save(file_path)

# %%
import os
from PIL import Image

false_folder="/home/vivek/Desktop/left" 
pixels_to_crop=15
for filename in os.listdir(false_folder):
    file_path=os.path.join(false_folder,filename)
    with Image.open(file_path) as img:
        crop_area=(pixels_to_crop, 0, img.width, img.height)
        cropped_img=img.crop(crop_area)
        cropped_img.save(file_path)
